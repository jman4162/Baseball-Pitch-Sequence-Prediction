# %% [markdown]
# # AutoGluon for Sports Analytics: Baseball Pitch Outcome Prediction
#
# Name: John Hodge
#
# Date: 04/19/24

# %% [markdown]
# ## Introduction
#
# Welcome to our tutorial on leveraging AutoGluon for sports analytics, specifically for the task of predicting baseball pitch types. AutoGluon, a powerful automated machine learning (AutoML) tool, simplifies the process of model building and deployment, making it accessible even to those with limited machine learning expertise. In this tutorial, we will guide you through the steps of installing dependencies, preparing your dataset, defining the prediction task, training the model, and making predictions. This hands-on guide aims to provide you with practical experience in using AutoGluon for real-world sports data, helping you unlock new insights and enhance your analytical capabilities.

# %% [markdown]
# ## Install dependencies

# %%
# !pip install autogluon
# Out:
# Requirement already satisfied: autogluon in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (1.1.0)
# Requirement already satisfied: autogluon.core==1.1.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.core[all]==1.1.0->autogluon) (1.1.0)
# Requirement already satisfied: autogluon.features==1.1.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon) (1.1.0)
# Requirement already satisfied: autogluon.tabular==1.1.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.tabular[all]==1.1.0->autogluon) (1.1.0)
# Requirement already satisfied: autogluon.multimodal==1.1.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon) (1.1.0)
# Requirement already satisfied: autogluon.timeseries==1.1.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.timeseries[all]==1.1.0->autogluon) (1.1.0)
# Requirement already satisfied: numpy<1.29,>=1.21 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (1.24.2)
# Requirement already satisfied: scipy<1.13,>=1.5.4 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (1.9.1)
# Requirement already satisfied: scikit-learn<1.4.1,>=1.3.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (1.4.0)
# Requirement already satisfied: networkx<4,>=3.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (3.2.1)
# Requirement already satisfied: pandas<2.3.0,>=2.0.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (2.1.4)
# Requirement already satisfied: tqdm<5,>=4.38 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (4.65.2)
# Requirement already satisfied: requests in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (2.28.2)
# Requirement already satisfied: matplotlib in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (3.8.4)
# Requirement already satisfied: boto3<2,>=1.10 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (1.34.88)
# Requirement already satisfied: autogluon.common==1.1.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (1.1.0)
# Requirement already satisfied: ray<2.11,>=2.10.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (2.10.0)
# Requirement already satisfied: hyperopt<0.2.8,>=0.2.7 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.core[all]==1.1.0->autogluon) (0.2.7)
# Requirement already satisfied: Pillow<11,>=10.0.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.multimodal==1.1.0->autogluon) (10.3.0)
# Requirement already satisfied: torch<2.2,>=2.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.multimodal==1.1.0->autogluon) (2.1.2)
# Requirement already satisfied: lightning<2.2,>=2.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.multimodal==1.1.0->autogluon) (2.1.4)
# Requirement already satisfied: transformers<4.39.0,>=4.38.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from transformers[sentencepiece]<4.39.0,>=4.38.0->autogluon.multimodal==1.1.0->autogluon) (4.38.2)
# Requirement already satisfied: accelerate<0.22.0,>=0.21.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.21.0)
# Requirement already satisfied: jsonschema<4.22,>=4.18 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.multimodal==1.1.0->autogluon) (4.21.1)
# Requirement already satisfied: seqeval<1.3.0,>=1.2.2 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.multimodal==1.1.0->autogluon) (1.2.2)
# Requirement already satisfied: evaluate<0.5.0,>=0.4.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.4.1)
# Requirement already satisfied: timm<0.10.0,>=0.9.5 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.9.16)
# Requirement already satisfied: torchvision<0.17.0,>=0.16.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.16.2)
# Requirement already satisfied: scikit-image<0.21.0,>=0.19.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.20.0)
# Requirement already satisfied: text-unidecode<1.4,>=1.3 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.multimodal==1.1.0->autogluon) (1.3)
# Requirement already satisfied: torchmetrics<1.3.0,>=1.2.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.multimodal==1.1.0->autogluon) (1.2.1)
# Requirement already satisfied: nptyping<2.5.0,>=1.4.4 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.multimodal==1.1.0->autogluon) (2.4.1)
# Requirement already satisfied: omegaconf<2.3.0,>=2.1.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.multimodal==1.1.0->autogluon) (2.2.3)
# Requirement already satisfied: pytorch-metric-learning<2.4,>=1.3.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.multimodal==1.1.0->autogluon) (2.3.0)
# Requirement already satisfied: nlpaug<1.2.0,>=1.1.10 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.multimodal==1.1.0->autogluon) (1.1.11)
# Requirement already satisfied: nltk<4.0.0,>=3.4.5 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.multimodal==1.1.0->autogluon) (3.8.1)
# Requirement already satisfied: openmim<0.4.0,>=0.3.7 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.3.9)
# Requirement already satisfied: defusedxml<0.7.2,>=0.7.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.7.1)
# Requirement already satisfied: jinja2<3.2,>=3.0.3 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.multimodal==1.1.0->autogluon) (3.1.3)
# Requirement already satisfied: tensorboard<3,>=2.9 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.multimodal==1.1.0->autogluon) (2.16.2)
# Requirement already satisfied: pytesseract<0.3.11,>=0.3.9 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.3.10)
# Requirement already satisfied: nvidia-ml-py3==7.352.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.multimodal==1.1.0->autogluon) (7.352.0)
# Requirement already satisfied: pdf2image<1.19,>=1.17.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.multimodal==1.1.0->autogluon) (1.17.0)
# Requirement already satisfied: xgboost<2.1,>=1.6 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.tabular[all]==1.1.0->autogluon) (2.0.3)
# Requirement already satisfied: fastai<2.8,>=2.3.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.tabular[all]==1.1.0->autogluon) (2.7.14)
# Requirement already satisfied: lightgbm<4.4,>=3.3 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.tabular[all]==1.1.0->autogluon) (4.3.0)
# Requirement already satisfied: catboost<1.2,>=1.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.tabular[all]==1.1.0->autogluon) (1.1.1)
# Requirement already satisfied: joblib<2,>=1.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (1.4.0)
# Requirement already satisfied: pytorch-lightning<2.2,>=2.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (2.1.4)
# Requirement already satisfied: gluonts<0.14.4,>=0.14.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.14.3)
# Requirement already satisfied: statsforecast<1.5,>=1.4.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (1.4.0)
# Requirement already satisfied: mlforecast<0.10.1,>=0.10.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.10.0)
# Requirement already satisfied: utilsforecast<0.0.11,>=0.0.10 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.0.10)
# Requirement already satisfied: orjson~=3.9 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (3.10.1)
# Requirement already satisfied: optimum<1.19,>=1.17 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon) (1.18.1)
# Requirement already satisfied: psutil<6,>=5.7.3 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.common==1.1.0->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (5.9.8)
# Requirement already satisfied: setuptools in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from autogluon.common==1.1.0->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (60.2.0)
# Requirement already satisfied: packaging>=20.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from accelerate<0.22.0,>=0.21.0->autogluon.multimodal==1.1.0->autogluon) (24.0)
# Requirement already satisfied: pyyaml in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from accelerate<0.22.0,>=0.21.0->autogluon.multimodal==1.1.0->autogluon) (6.0.1)
# Requirement already satisfied: botocore<1.35.0,>=1.34.88 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from boto3<2,>=1.10->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (1.34.88)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from boto3<2,>=1.10->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (0.10.0)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from boto3<2,>=1.10->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (0.10.1)
# Requirement already satisfied: graphviz in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from catboost<1.2,>=1.1->autogluon.tabular[all]==1.1.0->autogluon) (0.20.3)
# Requirement already satisfied: plotly in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from catboost<1.2,>=1.1->autogluon.tabular[all]==1.1.0->autogluon) (5.21.0)
# Requirement already satisfied: six in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from catboost<1.2,>=1.1->autogluon.tabular[all]==1.1.0->autogluon) (1.16.0)
# Requirement already satisfied: datasets>=2.0.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon) (2.19.0)
# Requirement already satisfied: dill in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon) (0.3.8)
# Requirement already satisfied: xxhash in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon) (3.4.1)
# Requirement already satisfied: multiprocess in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from fsspec[http]>=2021.05.0->evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon) (2024.3.1)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon) (0.22.2)
# Requirement already satisfied: responses<0.19 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon) (0.18.0)
# Requirement already satisfied: pip in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (24.0)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (0.0.7)
# Requirement already satisfied: fastcore<1.6,>=1.5.29 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (1.5.29)
# Requirement already satisfied: fastprogress>=0.2.4 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (1.0.3)
# Requirement already satisfied: spacy<4 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (3.7.4)
# Requirement already satisfied: pydantic<3,>=1.7 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from gluonts<0.14.4,>=0.14.0->autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (2.7.0)
# Requirement already satisfied: toolz~=0.10 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from gluonts<0.14.4,>=0.14.0->autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.12.1)
# Requirement already satisfied: typing-extensions~=4.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from gluonts<0.14.4,>=0.14.0->autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (4.11.0)
# Requirement already satisfied: future in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==1.1.0->autogluon) (1.0.0)
# Requirement already satisfied: cloudpickle in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==1.1.0->autogluon) (3.0.0)
# Requirement already satisfied: py4j in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==1.1.0->autogluon) (0.10.9.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from jinja2<3.2,>=3.0.3->autogluon.multimodal==1.1.0->autogluon) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.1.0->autogluon) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.1.0->autogluon) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.1.0->autogluon) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.1.0->autogluon) (0.18.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.8.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from lightning<2.2,>=2.1->autogluon.multimodal==1.1.0->autogluon) (0.11.2)
# Requirement already satisfied: numba in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from mlforecast<0.10.1,>=0.10.0->autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.59.1)
# Requirement already satisfied: window-ops in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from mlforecast<0.10.1,>=0.10.0->autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.0.15)
# Requirement already satisfied: gdown>=4.0.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.1.0->autogluon) (5.1.0)
# Requirement already satisfied: click in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from nltk<4.0.0,>=3.4.5->autogluon.multimodal==1.1.0->autogluon) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from nltk<4.0.0,>=3.4.5->autogluon.multimodal==1.1.0->autogluon) (2024.4.16)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from omegaconf<2.3.0,>=2.1.1->autogluon.multimodal==1.1.0->autogluon) (4.9.3)
# Requirement already satisfied: colorama in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (0.4.6)
# Requirement already satisfied: model-index in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (0.1.11)
# Requirement already satisfied: opendatalab in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (0.0.10)
# Requirement already satisfied: rich in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (13.4.2)
# Requirement already satisfied: tabulate in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (0.9.0)
# Requirement already satisfied: coloredlogs in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from optimum<1.19,>=1.17->optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon) (15.0.1)
# Requirement already satisfied: sympy in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from optimum<1.19,>=1.17->optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon) (1.12)
# Requirement already satisfied: onnx in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon) (1.16.0)
# Requirement already satisfied: onnxruntime>=1.11.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon) (1.16.3)
# Requirement already satisfied: protobuf>=3.20.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon) (4.25.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from pandas<2.3.0,>=2.0.0->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from pandas<2.3.0,>=2.0.0->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from pandas<2.3.0,>=2.0.0->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (2023.3)
# Requirement already satisfied: filelock in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from ray<2.11,>=2.10.0->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (3.13.3)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from ray<2.11,>=2.10.0->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (1.0.8)
# Requirement already satisfied: aiosignal in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from ray<2.11,>=2.10.0->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (1.3.1)
# Requirement already satisfied: frozenlist in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from ray<2.11,>=2.10.0->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (1.4.1)
# Requirement already satisfied: tensorboardX>=1.9 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (2.6.2.2)
# Requirement already satisfied: pyarrow>=6.0.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (15.0.2)
# Requirement already satisfied: aiohttp>=3.7 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (3.9.5)
# Requirement already satisfied: aiohttp-cors in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (0.7.0)
# Requirement already satisfied: colorful in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (0.5.6)
# Requirement already satisfied: py-spy>=0.2.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (0.3.14)
# Requirement already satisfied: opencensus in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (0.11.4)
# Requirement already satisfied: prometheus-client>=0.7.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (0.20.0)
# Requirement already satisfied: smart-open in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (6.4.0)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (20.25.3)
# Requirement already satisfied: grpcio>=1.32.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (1.62.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from requests->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/johnhodge/.local/lib/python3.9/site-packages (from requests->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/johnhodge/.local/lib/python3.9/site-packages (from requests->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from requests->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (2024.2.2)
# Requirement already satisfied: imageio>=2.4.1 in /Users/johnhodge/.local/lib/python3.9/site-packages (from scikit-image<0.21.0,>=0.19.1->autogluon.multimodal==1.1.0->autogluon) (2.9.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from scikit-image<0.21.0,>=0.19.1->autogluon.multimodal==1.1.0->autogluon) (2024.4.18)
# Requirement already satisfied: PyWavelets>=1.1.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from scikit-image<0.21.0,>=0.19.1->autogluon.multimodal==1.1.0->autogluon) (1.6.0)
# Requirement already satisfied: lazy_loader>=0.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from scikit-image<0.21.0,>=0.19.1->autogluon.multimodal==1.1.0->autogluon) (0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from scikit-learn<1.4.1,>=1.3.0->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (3.4.0)
# Requirement already satisfied: statsmodels>=0.13.2 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from statsforecast<1.5,>=1.4.0->autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.14.2)
# Requirement already satisfied: absl-py>=0.4 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.1.0->autogluon) (2.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.1.0->autogluon) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.1.0->autogluon) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.1.0->autogluon) (3.0.2)
# Requirement already satisfied: safetensors in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from timm<0.10.0,>=0.9.5->autogluon.multimodal==1.1.0->autogluon) (0.4.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from transformers<4.39.0,>=4.38.0->transformers[sentencepiece]<4.39.0,>=4.38.0->autogluon.multimodal==1.1.0->autogluon) (0.15.2)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from transformers[sentencepiece]<4.39.0,>=4.38.0->autogluon.multimodal==1.1.0->autogluon) (0.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from matplotlib->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from matplotlib->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from matplotlib->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from matplotlib->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from matplotlib->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (3.1.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from matplotlib->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (6.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from aiohttp>=3.7->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from aiohttp>=3.7->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from aiohttp>=3.7->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (4.0.3)
# Requirement already satisfied: pyarrow-hotfix in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon) (0.6)
# Requirement already satisfied: beautifulsoup4 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.1.0->autogluon) (4.12.3)
# Requirement already satisfied: zipp>=3.1.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (3.17.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<3,>=2.9->autogluon.multimodal==1.1.0->autogluon) (7.1.0)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from numba->mlforecast<0.10.1,>=0.10.0->autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.42.0)
# Requirement already satisfied: flatbuffers in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from onnxruntime>=1.11.0->optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon) (24.3.25)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from pydantic<3,>=1.7->gluonts<0.14.4,>=0.14.0->autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from pydantic<3,>=1.7->gluonts<0.14.4,>=0.14.0->autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (2.18.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (0.9.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (3.3.0)
# Requirement already satisfied: patsy>=0.5.6 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from statsmodels>=0.13.2->statsforecast<1.5,>=1.4.0->autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.5.6)
# Requirement already satisfied: distlib<1,>=0.3.7 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (0.3.8)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (4.2.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from coloredlogs->optimum<1.19,>=1.17->optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon) (10.0)
# Requirement already satisfied: ordered-set in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from model-index->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (4.1.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (2.18.0)
# Requirement already satisfied: pycryptodome in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (3.20.0)
# Requirement already satisfied: openxlab in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (0.0.38)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from plotly->catboost<1.2,>=1.1->autogluon.tabular[all]==1.1.0->autogluon) (8.2.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (2.17.2)
# Requirement already satisfied: mpmath>=0.19 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from sympy->optimum<1.19,>=1.17->optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon) (1.3.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (1.63.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (1.23.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (2.29.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (0.1.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from thinc<8.3.0,>=8.2.2->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from thinc<8.3.0,>=8.2.2->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (0.1.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from weasel<0.4.0,>=0.1.0->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (0.16.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from beautifulsoup4->gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.1.0->autogluon) (2.5)
# Requirement already satisfied: oss2~=2.17.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (2.17.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from requests[socks]->gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.1.0->autogluon) (1.7.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (4.9)
# Requirement already satisfied: crcmod>=1.7 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (1.7)
# Requirement already satisfied: aliyun-python-sdk-kms>=2.4.1 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (2.16.2)
# Requirement already satisfied: aliyun-python-sdk-core>=2.13.12 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (2.15.1)
# Requirement already satisfied: cryptography>=2.6.0 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (42.0.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (0.6.0)
# Requirement already satisfied: cffi>=1.12 in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (1.16.0)
# Requirement already satisfied: pycparser in /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (2.22)

# %%
import pandas as pd
import torch
from autogluon.tabular import TabularDataset, TabularPredictor

# %% [markdown]
# Check to see whether a CUDA-based GPU is available.

# %%
# Check to see whether a GPU is available
if torch.cuda.is_available():
    gpu_available = True
    print("GPU is available")
else:
    gpu_available = False
    print("GPU is not available")
# Out:
# GPU is not available

# %% [markdown]
# ## Load and Prepare Data
#
# We'll start by loading data from a CSV file. For this example, assume your CSV has columns for PitchType, Balls, Strikes, and PreviousPitchType. You might need to adjust the column names based on your actual data.
#
# Data preparation is a crucial step in any machine learning pipeline. For this tutorial, our data consists of various features related to baseball pitches, such as PitchType, Balls, Strikes, and PreviousPitchType.
#
# Effective data preparation enhances model accuracy by ensuring that the input data is suitably formatted and cleaned. This might include handling missing values, encoding categorical variables, and normalizing or scaling numerical features.

# %%
data_path = 'data/baseball_pitch_data.csv'

# Load the dataset
df = pd.read_csv(data_path)

# Create a new column 'PreviousPitchType' with the 'PitchType' from the previous row
df['PreviousPitchType'] = df['PitchType'].shift(1)

# Save the updated DataFrame back to CSV if needed
# df.to_csv('/path/to/your/updated_baseball_pitch_data.csv', index=False)

# Display the updated DataFrame to verify
# print(df.head(10))

# Truncate the DataFrame to N rows
num_truncation_rows = -1 # Number of rows to truncate to (-1 for all rows)
df_truncated = df[1:num_truncation_rows]

# Load data
data = TabularDataset(df_truncated)

# Preview data
print(data.head(10))

# Optionally, drop rows with missing values
data = data.dropna(subset=['PitchType', 'Balls', 'Strikes', 'PreviousPitchType'])

# Split data into training and testing datasets
train_data = data.sample(frac=0.8, random_state=42)  # 80% for training
test_data = data.drop(train_data.index)  # Remaining 20% for testing
# Out:
#     Balls  Strikes  PitchType Outcome PreviousPitchType
# 1       0        1   Changeup    ball          Fastball
# 2       1        1     Slider     hit          Changeup
# 3       0        0   Fastball  strike            Slider
# 4       0        1   Changeup  strike          Fastball
# 5       0        2   Fastball  strike          Changeup
# 6       0        0   Fastball     hit          Fastball
# 7       0        0   Fastball  strike          Fastball
# 8       0        1     Slider  strike          Fastball
# 9       0        2  Curveball    ball            Slider
# 10      1        2  Curveball  strike         Curveball

# %% [markdown]
# ## Define the Prediction Task
#
# With AutoGluon, you specify what column you're predicting. In this case, it's PitchType. AutoGluon will automatically handle feature processing. In supervised learning, specifying the target variable correctly is crucial because the model learns to predict this variable based on other input features.

# %%
label = 'Outcome'
print("Summary statistics of training data:")
print(train_data.describe())
# Out:
# Summary statistics of training data:
#                Balls        Strikes
# count  302558.000000  302558.000000
# mean        0.811121       0.874097
# std         0.942289       0.806010
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         1.000000       1.000000
# 75%         1.000000       2.000000
# max         3.000000       2.000000

# %% [markdown]
# ## Train the Model
#
# Now, train a model using AutoGluon. This can automatically handle categorical features, missing data, and more, but it’s still pivotal to understand how the training process works and what options you have available. AutoGluon automates many decisions and tasks such as feature selection, model selection, and hyperparameter tuning. It uses ensemble techniques to ensure robust predictions.
#
# More information on [AutoGluon presets](https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets).

# %%
MODELS_DIR = 'autogluon_pitchtype_models'  # Specifies folder to store trained models
MODEL_PRESET = 'good_quality'  # Preset for training models

if gpu_available:
    predictor = TabularPredictor(label=label, path=MODELS_DIR).fit(train_data, presets=MODEL_PRESET,
                                                                  num_gpus=1)
else:
    predictor = TabularPredictor(label=label, path=MODELS_DIR).fit(train_data, presets=MODEL_PRESET)
# Out:
# Presets specified: ['good_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Note: `save_bag_folds=False`! This will greatly reduce peak disk usage during fit (by ~8x), but runs the risk of an out-of-memory error during model refit if memory is small relative to the data size.
# 	You can avoid this risk by setting `save_bag_folds=True`.
# Dynamic stacking is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# Detecting stacked overfitting by sub-fitting AutoGluon on the input data. That is, copies of AutoGluon will be sub-fit on subset(s) of the data. Then, the holdout validation data is used to detect stacked overfitting.
# Sub-fit(s) time limit is: 3600 seconds.
# Starting holdout-based sub-fit for dynamic stacking. Context path is: autogluon_pitchtype_models/ds_sub_fit/sub_fit_ho.
# Running the sub-fit in a ray process to avoid memory leakage.
# Spend 1063 seconds for the sub-fit(s) during dynamic stacking.
# Time left for full fit of AutoGluon: 2537 seconds.
# Starting full fit now with num_stack_levels 0.
# Beginning AutoGluon training ... Time limit = 2537s
# AutoGluon will save models to "autogluon_pitchtype_models"
# =================== System Info ===================
# AutoGluon Version:  1.1.0
# Python Version:     3.9.0
# Operating System:   Darwin
# Platform Machine:   x86_64
# Platform Version:   Darwin Kernel Version 23.2.0: Wed Nov 15 21:54:05 PST 2023; root:xnu-10002.61.3~2/RELEASE_ARM64_T6031
# CPU Count:          14
# Memory Avail:       4.08 GB / 36.00 GB (11.3%)
# Disk Space Avail:   700.51 GB / 926.35 GB (75.6%)
# ===================================================
# Train Data Rows:    302558
# Train Data Columns: 4
# Label Column:       Outcome
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 3
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    4208.08 MB
# 	Train Data (Original)  Memory Usage: 41.90 MB (1.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('int', [])    : 2 | ['Balls', 'Strikes']
# 		('object', []) : 2 | ['PitchType', 'PreviousPitchType']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) : 2 | ['PitchType', 'PreviousPitchType']
# 		('int', [])      : 2 | ['Balls', 'Strikes']
# 	0.3s = Fit runtime
# 	4 features in original data used to generate 4 features in processed data.
# 	Train Data (Processed) Memory Usage: 5.19 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 0.51s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# Fitting 11 L1 models ...
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2536.49s of the 2536.49s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.76%)
# 	0.5525	 = Validation score   (accuracy)
# 	107.83s	 = Training   runtime
# 	1.23s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2427.26s of the 2427.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.24%)
# 	Warning: Exception caused LightGBMXT_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=8517, ip=127.0.0.1)
#   File "/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/lightgbm/__init__.py", line 8, in <module>
#     from .basic import Booster, Dataset, Sequence, register_logger
#   File "/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/lightgbm/basic.py", line 247, in <module>
#     _LIB = _load_lib()
#   File "/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/lightgbm/basic.py", line 232, in _load_lib
#     lib = ctypes.cdll.LoadLibrary(lib_path[0])
#   File "/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/ctypes/__init__.py", line 460, in LoadLibrary
#     return self._dlltype(name)
#   File "/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/ctypes/__init__.py", line 382, in __init__
#     self._handle = _dlopen(self._name, mode)
# OSError: dlopen(/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/lightgbm/lib/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <C3EB28DD-60B6-3334-AFA2-72BBBF9DBAEF> /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/lightgbm/lib/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=8517, ip=127.0.0.1)
#   File "/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 404, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/autogluon/core/models/abstract/abstract_model.py", line 855, in fit
#     out = self._fit(**kwargs)
#   File "/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/autogluon/tabular/models/lgb/lgb_model.py", line 98, in _fit
#     try_import_lightgbm()  # raise helpful error message if LightGBM isn't installed
#   File "/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/autogluon/common/utils/try_import.py", line 86, in try_import_lightgbm
#     raise ImportError("`import lightgbm` failed. If you are using Mac OSX, " "Please try 'brew install libomp'. Detailed info: {}".format(str(e)))
# ImportError: `import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/lightgbm/lib/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <C3EB28DD-60B6-3334-AFA2-72BBBF9DBAEF> /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/lightgbm/lib/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2426.01s of the 2426.01s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.14%)
# 	Warning: Exception caused LightGBM_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=8559, ip=127.0.0.1)
#   File "/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/lightgbm/__init__.py", line 8, in <module>
#     from .basic import Booster, Dataset, Sequence, register_logger
#   File "/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/lightgbm/basic.py", line 247, in <module>
#     _LIB = _load_lib()
#   File "/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/lightgbm/basic.py", line 232, in _load_lib
#     lib = ctypes.cdll.LoadLibrary(lib_path[0])
#   File "/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/ctypes/__init__.py", line 460, in LoadLibrary
#     return self._dlltype(name)
#   File "/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/ctypes/__init__.py", line 382, in __init__
#     self._handle = _dlopen(self._name, mode)
# OSError: dlopen(/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/lightgbm/lib/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <C3EB28DD-60B6-3334-AFA2-72BBBF9DBAEF> /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/lightgbm/lib/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=8559, ip=127.0.0.1)
#   File "/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 404, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/autogluon/core/models/abstract/abstract_model.py", line 855, in fit
#     out = self._fit(**kwargs)
#   File "/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/autogluon/tabular/models/lgb/lgb_model.py", line 98, in _fit
#     try_import_lightgbm()  # raise helpful error message if LightGBM isn't installed
#   File "/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/autogluon/common/utils/try_import.py", line 86, in try_import_lightgbm
#     raise ImportError("`import lightgbm` failed. If you are using Mac OSX, " "Please try 'brew install libomp'. Detailed info: {}".format(str(e)))
# ImportError: `import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/lightgbm/lib/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <C3EB28DD-60B6-3334-AFA2-72BBBF9DBAEF> /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/lightgbm/lib/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
# 2024-04-19 14:36:16,829	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-04-19 14:36:16,830	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-04-19 14:36:16,831	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-04-19 14:36:16,832	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-04-19 14:36:16,833	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-04-19 14:36:16,833	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 2424.92s of the 2424.92s of remaining time.
# 2024-04-19 14:36:16,834	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-04-19 14:36:21,950	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-04-19 14:36:21,951	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-04-19 14:36:21,952	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-04-19 14:36:21,952	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-04-19 14:36:21,953	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-04-19 14:36:21,953	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-04-19 14:36:21,954	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	0.5511	 = Validation score   (accuracy)
# 	2.4s	 = Training   runtime
# 	4.22s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 2418.21s of the 2418.21s of remaining time.
# 	0.5511	 = Validation score   (accuracy)
# 	2.12s	 = Training   runtime
# 	4.23s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 2411.79s of the 2411.79s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.17%)
# 	0.5497	 = Validation score   (accuracy)
# 	6.2s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 2404.66s of the 2404.66s of remaining time.
# 	0.5511	 = Validation score   (accuracy)
# 	1.85s	 = Training   runtime
# 	4.24s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 2398.5s of the 2398.5s of remaining time.
# 	0.5511	 = Validation score   (accuracy)
# 	1.87s	 = Training   runtime
# 	4.23s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 2392.33s of the 2392.33s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.49%)
# 	0.5521	 = Validation score   (accuracy)
# 	15.57s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 2375.69s of the 2375.69s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.03%)
# 	0.5524	 = Validation score   (accuracy)
# 	188.14s	 = Training   runtime
# 	1.01s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 2186.52s of the 2186.52s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.22%)
# 	Warning: Exception caused LightGBMLarge_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=8608, ip=127.0.0.1)
#   File "/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/lightgbm/__init__.py", line 8, in <module>
#     from .basic import Booster, Dataset, Sequence, register_logger
#   File "/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/lightgbm/basic.py", line 247, in <module>
#     _LIB = _load_lib()
#   File "/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/lightgbm/basic.py", line 232, in _load_lib
#     lib = ctypes.cdll.LoadLibrary(lib_path[0])
#   File "/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/ctypes/__init__.py", line 460, in LoadLibrary
#     return self._dlltype(name)
#   File "/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/ctypes/__init__.py", line 382, in __init__
#     self._handle = _dlopen(self._name, mode)
# OSError: dlopen(/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/lightgbm/lib/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <C3EB28DD-60B6-3334-AFA2-72BBBF9DBAEF> /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/lightgbm/lib/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=8608, ip=127.0.0.1)
#   File "/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 404, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/autogluon/core/models/abstract/abstract_model.py", line 855, in fit
#     out = self._fit(**kwargs)
#   File "/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/autogluon/tabular/models/lgb/lgb_model.py", line 98, in _fit
#     try_import_lightgbm()  # raise helpful error message if LightGBM isn't installed
#   File "/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/autogluon/common/utils/try_import.py", line 86, in try_import_lightgbm
#     raise ImportError("`import lightgbm` failed. If you are using Mac OSX, " "Please try 'brew install libomp'. Detailed info: {}".format(str(e)))
# ImportError: `import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/lightgbm/lib/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <C3EB28DD-60B6-3334-AFA2-72BBBF9DBAEF> /Users/johnhodge/opt/anaconda3/envs/py3_env/lib/python3.9/site-packages/lightgbm/lib/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 2185.38s of remaining time.
# 	Ensemble Weights: {'NeuralNetFastAI_BAG_L1': 0.941, 'CatBoost_BAG_L1': 0.059}
# 	0.5525	 = Validation score   (accuracy)
# 	2.45s	 = Training   runtime
# 	0.01s	 = Validation runtime
# AutoGluon training complete, total runtime = 354.11s ... Best model: "WeightedEnsemble_L2"
# Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_BAG_L1_FULL ...
# 2024-04-19 14:40:22,161	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-04-19 14:40:22,162	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-04-19 14:40:22,163	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-04-19 14:40:22,164	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-04-19 14:40:22,165	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-04-19 14:40:22,166	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-04-19 14:40:22,166	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	Stopping at the best epoch learned earlier - 13.
# 	45.87s	 = Training   runtime
# Fitting model: RandomForestGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	2.4s	 = Training   runtime
# 	4.22s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	2.12s	 = Training   runtime
# 	4.23s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_BAG_L1_FULL ...
# 	0.28s	 = Training   runtime
# Fitting model: ExtraTreesGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	1.85s	 = Training   runtime
# 	4.24s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	1.87s	 = Training   runtime
# 	4.23s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_BAG_L1_FULL ...
# 	0.73s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_BAG_L1_FULL ...
# 	67.77s	 = Training   runtime
# Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'NeuralNetFastAI_BAG_L1': 0.941, 'CatBoost_BAG_L1': 0.059}
# 	2.45s	 = Training   runtime
# Updated best model to "WeightedEnsemble_L2_FULL" (Previously "WeightedEnsemble_L2"). AutoGluon will default to using "WeightedEnsemble_L2_FULL" for predict() and predict_proba().
# Refit complete, total runtime = 115.12s ... Best model: "WeightedEnsemble_L2_FULL"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("autogluon_pitchtype_models")

# %% [markdown]
# ## Evaluate the Model
#
# After training, evaluating your model is crucial to understand its performance and to ensure it generalizes well on unseen data. Model evaluation typically involves calculating performance metrics such as accuracy, precision, recall, and F1-score on a test set that was not used during the training process. Once the model is trained, you can evaluate its performance on the test data:

# %%
performance = predictor.evaluate(test_data)
print(performance)
# Out:
# {'accuracy': 0.5498016922263352, 'balanced_accuracy': 0.3353163363028917, 'mcc': 0.022533727900984492}

# %% [markdown]
# ## View leaderboard

# %%
predictor.leaderboard(test_data)
# Out:
#                            model  score_test  score_val eval_metric  \
# 0            XGBoost_BAG_L1_FULL    0.551071        NaN    accuracy
# 1     NeuralNetTorch_BAG_L1_FULL    0.550225        NaN    accuracy
# 2        RandomForestGini_BAG_L1    0.550093   0.551147    accuracy
# 3          ExtraTreesEntr_BAG_L1    0.550093   0.551147    accuracy
# 4          ExtraTreesGini_BAG_L1    0.550093   0.551147    accuracy
# 5   RandomForestEntr_BAG_L1_FULL    0.550093        NaN    accuracy
# 6        RandomForestEntr_BAG_L1    0.550093   0.551147    accuracy
# 7   RandomForestGini_BAG_L1_FULL    0.550093        NaN    accuracy
# 8     ExtraTreesEntr_BAG_L1_FULL    0.550093        NaN    accuracy
# 9     ExtraTreesGini_BAG_L1_FULL    0.550093        NaN    accuracy
# 10   NeuralNetFastAI_BAG_L1_FULL    0.549802        NaN    accuracy
# 11      WeightedEnsemble_L2_FULL    0.549802        NaN    accuracy
# 12          CatBoost_BAG_L1_FULL    0.549524        NaN    accuracy
# 13           WeightedEnsemble_L2         NaN   0.552522    accuracy
# 14        NeuralNetFastAI_BAG_L1         NaN   0.552516    accuracy
# 15         NeuralNetTorch_BAG_L1         NaN   0.552446    accuracy
# 16                XGBoost_BAG_L1         NaN   0.552122    accuracy
# 17               CatBoost_BAG_L1         NaN   0.549739    accuracy
#
#     pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  \
# 0         0.118919            NaN    0.726267                 0.118919
# 1         0.223883            NaN   67.772540                 0.223883
# 2         0.107121       4.218421    2.404032                 0.107121
# 3         0.107458       4.225893    1.873344                 0.107458
# 4         0.108862       4.235048    1.852494                 0.108862
# 5         0.111210       4.230346    2.115787                 0.111210
# 6         0.111474       4.230346    2.115787                 0.111474
# 7         0.113438       4.218421    2.404032                 0.113438
# 8         0.118939       4.225893    1.873344                 0.118939
# 9         0.123439       4.235048    1.852494                 0.123439
# 10        0.329764            NaN   45.872117                 0.329764
# 11        0.359136            NaN   48.600251                 0.002504
# 12        0.026868            NaN    0.275787                 0.026868
# 13             NaN       1.367711  116.478410                      NaN
# 14             NaN       1.227467  107.829761                      NaN
# 15             NaN       1.008550  188.139505                      NaN
# 16             NaN       0.389998   15.567087                      NaN
# 17             NaN       0.126779    6.196302                      NaN
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                      NaN           0.726267            1       True
# 1                      NaN          67.772540            1       True
# 2                 4.218421           2.404032            1       True
# 3                 4.225893           1.873344            1       True
# 4                 4.235048           1.852494            1       True
# 5                 4.230346           2.115787            1       True
# 6                 4.230346           2.115787            1       True
# 7                 4.218421           2.404032            1       True
# 8                 4.225893           1.873344            1       True
# 9                 4.235048           1.852494            1       True
# 10                     NaN          45.872117            1       True
# 11                     NaN           2.452347            2       True
# 12                     NaN           0.275787            1       True
# 13                0.013465           2.452347            2      False
# 14                1.227467         107.829761            1      False
# 15                1.008550         188.139505            1      False
# 16                0.389998          15.567087            1      False
# 17                0.126779           6.196302            1      False
#
#     fit_order
# 0          16
# 1          17
# 2           2
# 3           6
# 4           5
# 5          12
# 6           3
# 7          11
# 8          15
# 9          14
# 10         10
# 11         18
# 12         13
# 13          9
# 14          1
# 15          8
# 16          7
# 17          4

# %% [markdown]
# ## Make Predictions
#
# Once satisfied with your model's performance, the final step is using it to make predictions on new data. This step is where your model is put to the test, providing insights and decisions based on the data it analyzes. Now you can use the model to predict the pitch type:

# %%
predictions = predictor.predict(test_data)
print(predictions.head())

# To view the probability of each class
probabilities = predictor.predict_proba(test_data)
print(probabilities.head())
# Out:
# 6     strike
# 14    strike
# 16    strike
# 19    strike
# 20    strike
# Name: Outcome, dtype: object
#         ball       hit    strike
# 6   0.303388  0.118411  0.578201
# 14  0.442720  0.097562  0.459719
# 16  0.405308  0.107504  0.487188
# 19  0.426240  0.102519  0.471241
# 20  0.302796  0.118424  0.578780

# %% [markdown]
# ## Insights and Feature Importance
#
# AutoGluon provides functionality to understand which features are most important for the predictions:

# %%
feature_importance = predictor.feature_importance(data=train_data)
print(feature_importance)
# Out:
# Computing feature importance via permutation shuffling for 4 features using 5000 rows with 5 shuffle sets...
# 	1.09s	= Expected runtime (0.22s per shuffle set)
# 	0.73s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                    importance    stddev   p_value  n  p99_high   p99_low
# PitchType             0.00264  0.001640  0.011373  5  0.006016 -0.000736
# PreviousPitchType     0.00000  0.000000  0.500000  5  0.000000  0.000000
# Strikes              -0.00008  0.002292  0.529234  5  0.004639 -0.004799
# Balls                -0.00024  0.002251  0.588351  5  0.004395 -0.004875

# %% [markdown]
# The results show that only PitchType is salient in predicting the outcome of the pitch in this data set. The count (balls and strikes) and previous pitch are found to not be salients, which makes sense for the data set based on how the data set was trained using a Markov model.

# %% [markdown]
# ## Conclusion
#
# In this tutorial, we explored the capabilities of AutoGluon in the context of sports analytics by predicting baseball pitch types. We walked through the entire workflow, from data preparation and model training to evaluation and making predictions. By now, you should have a solid understanding of how AutoGluon can be used to handle complex predictive modeling tasks with ease. We encourage you to apply the knowledge and techniques learned here to your datasets and challenges, exploring further the potential of AutoML to transform your analytical processes. Remember, the key to mastering AutoGluon is continuous experimentation and adaptation to your specific needs. Experiment with AutoGluon's hyperparameters and model configurations to improve performance.
#
# ## Next steps
#
# Run the predictor model again using a data set that contains more complex probabilistic pitch sequences using longer Markov chains.
